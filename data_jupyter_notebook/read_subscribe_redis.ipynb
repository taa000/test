# %%
import redis

# %%
r = redis.Redis()
p = r.pubsub()
p.subscribe('Paket_Satu')
for i in range (9999999):
    message = p.get_message() 
    if message: 
        command = message['data']
        print(command)
# Out:
# 1
# b"['20200226', '030042', '00000743', 'AKKU', None, None, None, None, '000000000000']"
# b"['20200226', '030042', '00000744', 'AKPI', None, None, None, None, '000000000000']"
# b"['20200226', '030042', '00000745', 'AKRA', None, None, None, None, '000000000000']"
# b"['20200226', '030042', '00000746', 'AKSI', None, None, None, None, '000000000000']"
# b"['20200226', '030042', '00000747', 'ALDO', None, None, None, None, '000000000000']"
# b"['20200226', '030042', '00000748', 'ALKA', '00000000130.00', '00000000130.00', '00000000130.00', '00000000130.00', '000000000000']"
# b"['20200226', '030042', '00000749', 'ALMI', None, None, None, None, '000000000000']"
# b"['20200226', '030042', '00000750', 'ALTO', None, None, None, None, '000000000000']"
# b"['20200226', '030042', '00000751', 'AMAG', '00000000398.00', '00000000398.00', '00000000398.00', '00000000398.00', '000000000000']"
# b"['20200226', '030042', '00000752', 'AMFG', None, None, None, None, '000000000000']"
# ...
